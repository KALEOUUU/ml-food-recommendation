# %% [markdown]
# # Data Preparation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Dataset/drink-nutrition.csv')
df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'food', 'Caloric Value', 'Fat',
#        'Saturated Fats', 'Monounsaturated Fats', 'Polyunsaturated Fats',
#        'Carbohydrates', 'Sugars', 'Protein', 'Dietary Fiber', 'Cholesterol',
#        'Sodium', 'Water', 'Vitamin A', 'Vitamin B1', 'Vitamin B11',
#        'Vitamin B12', 'Vitamin B2', 'Vitamin B3', 'Vitamin B5', 'Vitamin B6',
#        'Vitamin C', 'Vitamin D', 'Vitamin E', 'Vitamin K', 'Calcium', 'Copper',
#        'Iron', 'Magnesium', 'Manganese', 'Phosphorus', 'Potassium', 'Selenium',
#        'Zinc', 'Nutrition Density'],
#       dtype='object')

# %% [markdown]
# ## Rename selected column

# %%
df_drink = df.rename(columns={'Caloric Value': 'calories', 'Protein': 'proteins', 'Fat': 'fat', 'Carbohydrates': 'carbohydrate', 'food': 'name'})

# %%
selected_columns_drink = df_drink[['name', 'calories', 'fat', 'proteins', 'carbohydrate']]
selected_columns_drink
# Out:
#                            name  calories   fat  proteins  carbohydrate
# 0    chocolate pudding fat free       105   0.3       2.2          23.6
# 1               tapioca pudding       143   4.3       2.1          23.9
# 2      tapioca pudding fat free       105   0.4       1.6          23.9
# 3                  rice pudding       122   2.4       3.6          20.8
# 4                  corn pudding       328  12.6      11.1          42.4
# ..                          ...       ...   ...       ...           ...
# 227       muesli master crumble       124   2.4       2.4           4.5
# 228                 bran flakes       131   0.8       4.0          32.2
# 229                  nut cereal       245   5.9       4.0          46.2
# 230                 corn flakes       108   0.3       1.7          24.6
# 231              corn grits dry        36   0.2       0.7           7.7
#
# [232 rows x 5 columns]

# %%
df_fruit = pd.read_csv('Dataset/fruit-nutrition.csv')
df_fruit
# Out:
#      Unnamed: 0.1  Unnamed: 0                         food  Caloric Value  \
# 0               0           0                    nectarine             66
# 1               1           1               kiwifruit gold             51
# 2               2           2             prickly pear raw              8
# 3               3           3                    pineapple             45
# 4               4           4                        rowan            253
# ..            ...         ...                          ...            ...
# 566           566         566           turkey wing cooked            426
# 567           567         567               goose meat raw           6077
# 568           568         568        turkey breast roasted           3266
# 569           569         569        chicken fajita strips             13
# 570           570         570  crispy chicken strips tyson            145
#
#          Fat  Saturated Fats  Monounsaturated Fats  Polyunsaturated Fats  \
# ...

# %%
df_fruit = df.rename(columns={'Caloric Value': 'calories', 'Protein': 'proteins', 'Fat': 'fat', 'Carbohydrates': 'carbohydrate', 'food': 'name'})

# %%
selected_columns_fruit = df_fruit[['name', 'calories', 'fat', 'proteins', 'carbohydrate']]
selected_columns_fruit
# Out:
#                            name  calories   fat  proteins  carbohydrate
# 0    chocolate pudding fat free       105   0.3       2.2          23.6
# 1               tapioca pudding       143   4.3       2.1          23.9
# 2      tapioca pudding fat free       105   0.4       1.6          23.9
# 3                  rice pudding       122   2.4       3.6          20.8
# 4                  corn pudding       328  12.6      11.1          42.4
# ..                          ...       ...   ...       ...           ...
# 227       muesli master crumble       124   2.4       2.4           4.5
# 228                 bran flakes       131   0.8       4.0          32.2
# 229                  nut cereal       245   5.9       4.0          46.2
# 230                 corn flakes       108   0.3       1.7          24.6
# 231              corn grits dry        36   0.2       0.7           7.7
#
# [232 rows x 5 columns]

# %%
df_indonesia = pd.read_csv('Dataset/indonesia-food-nutrition.csv')
df_indonesia
# Out:
#       calories  proteins   fat  carbohydrate                name     Meal Type
# 0        280.0       9.2  28.4           0.0                Abon  Lunch/Dinner
# 1        513.0      23.7  37.0          21.3        Abon haruwan  Lunch/Dinner
# 2          0.0       0.0   0.2           0.0           Agar-agar  Lunch/Dinner
# 3         45.0       1.1   0.4          10.8  Akar tonjong segar         Snack
# 4         37.0       4.4   0.5           3.8       Aletoge segar  Lunch/Dinner
# ...        ...       ...   ...           ...                 ...           ...
# 1341      42.0       1.2   0.6           9.3        Wortel Segar         Snack
# 1342      37.0       1.0   0.6           8.3        Wortel kukus         Snack
# 1343      28.0       0.7   0.5           6.3        Wortel rebus         Snack
# 1344     254.0       3.0   1.1          58.1              Yangko     Breakfast
# 1345      52.0       3.3   2.5           4.0             Yoghurt         Snack
#
# [1346 rows x 6 columns]

# %%
df_ingridient = pd.read_csv('Dataset/ingridient-nutrition.csv')
df_ingridient
# Out:
#      Unnamed: 0.1  Unnamed: 0                      food  Caloric Value  \
# 0               0           0    margarine with yoghurt             88
# 1               1           1     sunflower seed butter             99
# 2               2           2              hazelnut oil            120
# 3               3           3         menhaden fish oil           1966
# 4               4           4        cod liver fish oil            123
# ..            ...         ...                       ...            ...
# 717           717         717                  jews ear             25
# 718           718         718           enoki mushrooms              1
# 719           719         719           morel mushrooms              4
# 720           720         720  portabella mushrooms raw             19
# 721           721         721           oyster mushroom              5
#
#          Fat  Saturated Fats  Monounsaturated Fats  Polyunsaturated Fats  \
# ...

# %%
df_ingridient = df.rename(columns={'Caloric Value': 'calories', 'Protein': 'proteins', 'Fat': 'fat', 'Carbohydrates': 'carbohydrate', 'food': 'name'})

# %%
selected_columns_ingridient = df_ingridient[['name', 'calories', 'fat', 'proteins', 'carbohydrate']]
selected_columns_ingridient
# Out:
#                            name  calories   fat  proteins  carbohydrate
# 0    chocolate pudding fat free       105   0.3       2.2          23.6
# 1               tapioca pudding       143   4.3       2.1          23.9
# 2      tapioca pudding fat free       105   0.4       1.6          23.9
# 3                  rice pudding       122   2.4       3.6          20.8
# 4                  corn pudding       328  12.6      11.1          42.4
# ..                          ...       ...   ...       ...           ...
# 227       muesli master crumble       124   2.4       2.4           4.5
# 228                 bran flakes       131   0.8       4.0          32.2
# 229                  nut cereal       245   5.9       4.0          46.2
# 230                 corn flakes       108   0.3       1.7          24.6
# 231              corn grits dry        36   0.2       0.7           7.7
#
# [232 rows x 5 columns]

# %%
df_snack = pd.read_csv('Dataset/snack-nutrition.csv')
df_snack
# Out:
#      Unnamed: 0.1  Unnamed: 0                              food  \
# 0               0           0                      cream cheese
# 1               1           1                 neufchatel cheese
# 2               2           2  requeijao cremoso light catupiry
# 3               3           3                    ricotta cheese
# 4               4           4              cream cheese low fat
# ..            ...         ...                               ...
# 546           546         546             chinook salmon smoked
# 547           547         547                      cisco smoked
# 548           548         548                    haddock smoked
# 549           549         549                  whitefish smoked
# 550           550         550  red salmon sockeye filets smoked
#
#      Caloric Value   Fat  Saturated Fats  Monounsaturated Fats  \
# 0               51   5.0           2.900                 1.300
# 1              215  19.4          10.900                 4.900
# ...

# %%
df_snack = df.rename(columns={'Caloric Value': 'calories', 'Protein': 'proteins', 'Fat': 'fat', 'Carbohydrates': 'carbohydrate', 'food': 'name'})

# %%
selected_columns_snack = df_snack[['name', 'calories', 'fat', 'proteins', 'carbohydrate']]
selected_columns_snack
# Out:
#                            name  calories   fat  proteins  carbohydrate
# 0    chocolate pudding fat free       105   0.3       2.2          23.6
# 1               tapioca pudding       143   4.3       2.1          23.9
# 2      tapioca pudding fat free       105   0.4       1.6          23.9
# 3                  rice pudding       122   2.4       3.6          20.8
# 4                  corn pudding       328  12.6      11.1          42.4
# ..                          ...       ...   ...       ...           ...
# 227       muesli master crumble       124   2.4       2.4           4.5
# 228                 bran flakes       131   0.8       4.0          32.2
# 229                  nut cereal       245   5.9       4.0          46.2
# 230                 corn flakes       108   0.3       1.7          24.6
# 231              corn grits dry        36   0.2       0.7           7.7
#
# [232 rows x 5 columns]

# %%
df_fruit_selected = selected_columns_fruit.copy()
df_drink_selected = selected_columns_drink.copy()

# %%
df_indonesia_selected = df_indonesia.copy()
df_ingridient_selected = selected_columns_ingridient.copy()
df_snack_selected = selected_columns_snack.copy()

# %%
df_general = pd.concat([df_fruit_selected, df_drink_selected, df_indonesia_selected, df_snack_selected, df_ingridient_selected], ignore_index=True)

# %%
df_general
# Out:
#                             name  calories   fat  proteins  carbohydrate  \
# 0     chocolate pudding fat free     105.0   0.3       2.2          23.6
# 1                tapioca pudding     143.0   4.3       2.1          23.9
# 2       tapioca pudding fat free     105.0   0.4       1.6          23.9
# 3                   rice pudding     122.0   2.4       3.6          20.8
# 4                   corn pudding     328.0  12.6      11.1          42.4
# ...                          ...       ...   ...       ...           ...
# 2269       muesli master crumble     124.0   2.4       2.4           4.5
# 2270                 bran flakes     131.0   0.8       4.0          32.2
# 2271                  nut cereal     245.0   5.9       4.0          46.2
# 2272                 corn flakes     108.0   0.3       1.7          24.6
# 2273              corn grits dry      36.0   0.2       0.7           7.7
#
#      Meal Type
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# ...

# %% [markdown]
# ## Categorize dataset

# %%
def categorize_complete_meal_type(row):
    name = row["name"].lower()
    
    # Drinks
    if any(x in name for x in ["juice", "coffee", "tea", "milk", "soda", "beer", "wine", "drink", "beverage", 'kopi', 'teh', 'sirup', 'sari kedelai', 'es', 'jus', 
                               'susu', 'cendol', 'daun teh', 'bir', 'limun', 'bandrek', 'kelapa', 'nectar', 'fruit', 'cola', 'coke', 'tonic', 'water', 'coconut', 'sprite', 'limeade', 'lemonade']):
        return "Drink"
    
    # Carbs
    elif any(x in name for x in ["rice", "corn", "potato", "bread", "pasta", "noodle", "cereal", "oat", "wheat", "barley", 'nasi', 
                                 'roti', 'kentang', 'jagung', 'beras', 'kacang', 'talas', 'sukun', 'ubi', 'umbi', 'bihun', 'makaroni', 'tapioka', 'singkong', 'emping', 'gaplek', 'tepung', 'ketan', 'sagu', 'mie', 'bakso', 'lontong']):
        return "Carbs"
    
    # Breakfast
    elif any(x in name for x in ["oat", "cereal", "bread", "toast", "pancake", "waffle", "muffin", "yogurt", "egg", 'ketan', 'bubur', 'biskuit', 'kue', 'martabak', 'serabi', 'lupis', 'roti bakar', 'peuyeum']):
        return "Breakfast"
    
    # Lunch
    elif any(x in name for x in ["rice", "pasta", "noodle", "beef", "chicken", "fish", "soup", "vegetable", "lentil", "stew", 'bebek', 'ayam', 'ikan', 'sop', 'mi', 'mie', 'sayur', 'rendang', 'soto', 'telur', 'tahu', 'tempe', 'gulai', 
                                 'sayur asem', 'bakmi', 'pecel', 'opor', 'lodeh', 'rawon', 'tongseng', 'gudeg', "salad", "soup", "grilled", "steak", "seafood", "fish", "lentil", 'sup', 'ikan', 'steak', 'pecel', 'gado-gado', 
                                 'capcay', 'asinan', 'karedok', 'urap', 'daging', 'sapi', 'sate', 'abon', 'empal', 'sate', 'belut', 'kangkung', 'coto', 'koro', 'teri', 'sphagetty', 'semur']):
        return "Lunch/Dinner"

    # Snack
    elif any(x in name for x in ["cookie", "candy", "chocolate", "ice cream", "cracker", "chip", "bar", "snack", "popcorn", 'keripik', 'kerupuk', 'kue', 'pisang', 'jambu', 'jeruk', 'karoket', 'kelepon', 'kembang', 'ketela', 'onde-onde', 
                                 'bika', 'dodol', 'wingko', 'es', 'lemper', 'arem-arem', 'kue cubit', 'nastar', 'kastengel', 'lapis legit', 'mochi', 'getuk', 'cucur', 'biji salak', 'misro', 'combro', 'pudding', 'buah', 'mangga', 'markisa', 
                                 'ongol', 'pepaya', 'rambutan', 'siomay', 'tahu', 'tempe', 'granola', 'alpukat', 'pempek', 'oncom', 'lopis', 'manggis', 'nanas', 'nangka', 'olah-olah', 'papeda', 'pastel', 'ongol-ongol', 'sawo', 'srikaya', 'semangka', 'peanuts', 'seed', 'roasted', 'kelapa', 'wortel']):
        return "Snack"

    return "ingrideint"

df_general["Meal Type"] = df_general.apply(categorize_complete_meal_type, axis=1)
df_general["Meal Type"].value_counts()
# Out:
# Meal Type
# Drink           580
# ingrideint      579
# Lunch/Dinner    380
# Carbs           351
# Snack           308
# Breakfast        76
# Name: count, dtype: int64

# %%
df_general['Meal Type']
# Out:
# 0       Drink
# 1       Snack
# 2       Snack
# 3       Carbs
# 4       Carbs
#         ...
# 2269    Drink
# 2270    Drink
# 2271    Carbs
# 2272    Drink
# 2273    Carbs
# Name: Meal Type, Length: 2274, dtype: object

# %%
df_general[df_general['Meal Type'] == 'Breakfast']
# Out:
#                                          name  calories   fat  proteins  \
# 13                     vanilla yogurt low fat     208.0   3.1    12.100
# 14           classique yogurt plain 2 liberte      30.0   1.2     3.300
# 15    yoplait light strawberry yogurt yoplait      79.0   0.0     0.000
# 16                             vanilla yogurt     145.0   2.1     8.400
# 18                             yogurt parfait     125.0   1.5     5.000
# ...                                       ...       ...   ...       ...
# 2069    triple zero greek yogurt dannon oikos     120.0   0.0     0.038
# 2070                             greek yogurt     100.0   0.7    17.300
# 2073                                egg fried      90.0   6.8     6.300
# 2079                                egg large     138.0   9.3     0.000
# 2234                  sunflower seeds toasted     829.0  76.1    23.100
#
#       carbohydrate  Meal Type
# 13          33.800  Breakfast
# 14           1.700  Breakfast
# ...

# %%
df_general[df_general['Meal Type'] == 'Lunch/Dinner']
# Out:
#                         name  calories   fat  proteins  carbohydrate  \
# 10            zaziki milfina      51.0   4.4       0.0           0.0
# 149              cumin seeds       8.0   0.5       0.4           0.9
# 184   macadamia nuts roasted     215.0  22.8       2.3           4.0
# 202       mixed nuts roasted     178.0  15.4       5.2           7.6
# 215       macadamia nuts raw      38.0   4.0       0.4           0.7
# ...                      ...       ...   ...       ...           ...
# 2052          zaziki milfina      51.0   4.4       0.0           0.0
# 2191             cumin seeds       8.0   0.5       0.4           0.9
# 2226  macadamia nuts roasted     215.0  22.8       2.3           4.0
# 2244      mixed nuts roasted     178.0  15.4       5.2           7.6
# 2257      macadamia nuts raw      38.0   4.0       0.4           0.7
#
#          Meal Type
# 10    Lunch/Dinner
# 149   Lunch/Dinner
# 184   Lunch/Dinner
# 202   Lunch/Dinner
# 215   Lunch/Dinner
# ...

# %%
df_general.shape
# Out:
# (2274, 6)

# %% [markdown]
# ## Dataset Distribution

# %%
meal_counts = df_general['Meal Type'].value_counts()

plt.figure(figsize=(8, 6))
plt.pie(meal_counts, labels=meal_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Meal Types')
plt.show()

# %% [markdown]
# # Save dataset

# %%
df_general.to_csv('Dataset/food-nutrition.csv', index=False)
